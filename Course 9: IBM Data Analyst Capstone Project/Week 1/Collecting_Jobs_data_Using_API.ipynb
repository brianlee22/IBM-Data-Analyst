# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Collecting Job Data Using APIs**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# *   Collect job data from Jobs API
# *   Store the collected data into an excel spreadsheet.

# %% [markdown]
# > <strong>Note: Before starting with the assignment make sure to read all the instructions and then move ahead with the coding part.</strong>

# %% [markdown]
# #### Instructions

# %% [markdown]
# To run the actual lab, firstly you need to click on the [Jobs_API](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Jobs_API.ipynb) notebook link. The file contains flask code which is required to run the Jobs API data.
#
# Now, to run the code in the file that opens up follow the below steps.
#
# Step1: Download the file.
#
# Step2: Upload it on the IBM Watson studio. (If IBM Watson Cloud service does not work in your system, follow the alternate Step 2 below)
#
# Step2(alternate): Upload it in your SN labs environment using the upload button which is highlighted in red in the image below:
# Remember to upload this Jobs_API file in the same folder as your current .ipynb file
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/Upload.PNG" />
#
# Step3:  Run all the cells of the Jobs_API file. (Even if you receive an asterik sign after running the last cell, the code works fine.)
#
# If you want to learn more about flask, which is optional, you can click on this link [here](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/FLASK_API.md.html).
#
# Once you run the flask code, you can start with your assignment.

# %% [markdown]
# ## Dataset Used in this Assignment
#
# The dataset used in this lab comes from the following source: [https://www.kaggle.com/promptcloud/jobs-on-naukricom](https://www.kaggle.com/promptcloud/jobs-on-naukricom?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01) under the under a **Public Domain license**.
#
# > Note: We are using a modified subset of that dataset for the lab, so to follow the lab instructions successfully please use the dataset provided with the lab, rather than the dataset from the original source.
#
# The original dataset is a csv. We have converted the csv to json as per the requirement of the lab.

# %% [markdown]
# ## Warm-Up Exercise

# %% [markdown]
# Before you attempt the actual lab, here is a fully solved warmup exercise that will help you to learn how to access an API.

# %% [markdown]
# Using an API, let us find out who currently are on the International Space Station (ISS).<br> The API at [http://api.open-notify.org/astros.json](http://api.open-notify.org/astros.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ) gives us the information of astronauts currently on ISS in json format.<br>
# You can read more about this API at [http://open-notify.org/Open-Notify-API/People-In-Space/](http://open-notify.org/Open-Notify-API/People-In-Space?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %%
import requests # you need this module to make an API call
import pandas as pd

# %%
api_url = "http://api.open-notify.org/astros.json" # this url gives use the astronaut data

# %%
response = requests.get(api_url) # Call the API using the get method and store the
                                # output of the API call in a variable called response.

# %%
if response.ok:             # if all is well() no errors, no network timeouts)
    data = response.json()  # store the result in json format in a variable called data
                            # the variable data is of type dictionary.

# %%
print(data)   # print the data just to check the output or for debugging
# Out:
# {'number': 10, 'people': [{'name': 'Oleg Artemyev', 'craft': 'ISS'}, {'name': 'Denis Matveev', 'craft': 'ISS'}, {'name': 'Sergey Korsakov', 'craft': 'ISS'}, {'name': 'Kjell Lindgren', 'craft': 'ISS'}, {'name': 'Bob Hines', 'craft': 'ISS'}, {'name': 'Samantha Cristoforetti', 'craft': 'ISS'}, {'name': 'Jessica Watkins', 'craft': 'ISS'}, {'name': 'Cai Xuzhe', 'craft': 'Tiangong'}, {'name': 'Chen Dong', 'craft': 'Tiangong'}, {'name': 'Liu Yang', 'craft': 'Tiangong'}], 'message': 'success'}

# %% [markdown]
# Print the number of astronauts currently on ISS.

# %%
print(data.get('number'))
# Out:
# 10

# %% [markdown]
# Print the names of the astronauts currently on ISS.

# %%
astronauts = data.get('people')
print("There are {} astronauts on ISS".format(len(astronauts)))
print("And their names are :")
for astronaut in astronauts:
    print(astronaut.get('name'))
# Out:
# There are 10 astronauts on ISS
# And their names are :
# Oleg Artemyev
# Denis Matveev
# Sergey Korsakov
# Kjell Lindgren
# Bob Hines
# Samantha Cristoforetti
# Jessica Watkins
# Cai Xuzhe
# Chen Dong
# Liu Yang

# %% [markdown]
# Hope the warmup was helpful. Good luck with your next lab!

# %% [markdown]
# ## Lab: Collect Jobs Data using Jobs API

# %% [markdown]
# ### Objective: Determine the number of jobs currently open for various technologies  and for various locations

# %% [markdown]
# Collect the number of job postings for the following locations using the API:
#
# *   Los Angeles
# *   New York
# *   San Francisco
# *   Washington DC
# *   Seattle
# *   Austin
# *   Detroit

# %%
#Import required libraries
import pandas as pd
import json

# %% [markdown]
# #### Write a function to get the number of jobs for the Python technology.<br>
#
# > Note: While using the lab you need to pass the **payload** information for the **params** attribute in the form of **key** **value** pairs.
#
# Refer the ungraded **rest api lab** in the course **Python for Data Science, AI & Development**  <a href="https://www.coursera.org/learn/python-for-applied-data-science-ai/ungradedLti/P6sW8/hands-on-lab-access-rest-apis-request-http?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01">link</a>
#
# ##### The keys in the json are
#
# *   Job Title
#
# *   Job Experience Required
#
# *   Key Skills
#
# *   Role Category
#
# *   Location
#
# *   Functional Area
#
# *   Industry
#
# *   Role
#
# You can also view  the json file contents  from the following <a href = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/module%201/Accessing%20Data%20Using%20APIs/jobs.json?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01">json</a> URL.

# %%
api_url = "http://127.0.0.1:5000/data"
response_test = requests.get(api_url)
data_test = response_test.json()
print(data_test)
# Out:
# None

# %%
payload = {"Key Skills": 'Python'}
api_url = "http://127.0.0.1:5000/data"
response = requests.get(api_url, params=payload)
data = response.json()

# %%
data
#print(data)
# Out:
# [{'Functional Area': 'IT Hardware , Technical Support , Telecom Engineering',
#   'Id': 38,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '15 - 20 yrs',
#   'Job Title': 'nutanix sme',
#   'Key Skills': 'Troubleshooting| DNS| DHCP| Monitoring| Virtualization| Shell scripting|Python| VMS| Open source| Archiving',
#   'Location': 'Washington DC',
#   'Role': 'Technical Support Manager',
#   'Role Category': 'Technical Support'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 73,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '6 - 11 yrs',
#   'Job Title': 'Openstack Engineer / Openstack Admin with Ceph Storage',
#   'Key Skills': 'cloud| puppet|Python| git| KVM| linux| jenkins| openstack| ansible',
#   'Location': 'Washington DC',
#   'Role': 'System Analyst',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'Analytics & Business Intelligence',
#   'Id': 117,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '4 - 9 yrs',
#   'Job Title': 'Manager/senior Manager- Analytics- Life & Annuities - Insurance Domain',
#   'Key Skills': 'Predictive Modeling| SAS| Data Management| Data Mining| Tableau| Data Analytics| Statistics| Analytics| SQL|Python',
#   'Location': 'Los Angeles',
#   'Role': 'Analytics Manager',
#   'Role Category': 'Analytics & BI'},
#  {'Functional Area': 'IT Software - Network Administration , Security',
#   'Id': 147,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '4 - 8 yrs',
#   'Job Title': 'IT Security Head',
#   'Key Skills': 'C|Python| Six Sigma| PMP| .NET| HTML| JavaScript| SQL| Oracle| assembly language| Real Time Operating Systems',
#   'Location': 'Los Angeles',
#   'Role': 'Head/VP/GM-Technology(IT)/CTO',
#   'Role Category': 'Senior Management'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 156,
#   'Industry': 'Recruitment, Staffing',
#   'Job Experience Required': '1 - 3 yrs',
#   'Job Title': 'Python Developer',
#   'Key Skills': 'Python',
#   'Location': 'Los Angeles',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 165,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '3 - 5 yrs',
#   'Job Title': 'Quality Assurance Engineer',
#   'Key Skills': 'assembly language| Six Sigma| PMP| C| JavaScript| .NET| HTML| Oracle|Python| SQL',
#   'Location': 'Los Angeles',
#   'Role': 'Quality Assurance/Quality Control Executive',
#   'Role Category': 'QA/Testing/Documentation'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 199,
#   'Industry': 'Banking, Financial Services, Broking',
#   'Job Experience Required': '1 - 5 yrs',
#   'Job Title': 'Java Software Engineer',
#   'Key Skills': 'Linux| Agile|Python| Computer science| Coding| Fixed income| Machine learning| Asset management| JIRA| Financial services',
#   'Location': 'Los Angeles',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 217,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '0 - 1 yrs',
#   'Job Title': 'Python Developer',
#   'Key Skills': 'Debugging| Troubleshooting|Python| Interpersonal skills| OOPS| Programming| developer',
#   'Location': 'Los Angeles',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 278,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '5 - 8 yrs',
#   'Job Title': 'Devops Engineer - Tools & Automation',
#   'Key Skills': 'Python| open source| database| Automation| java| linux| perl| Monitoring| nosql',
#   'Location': 'Los Angeles',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 297,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '3 - 8 yrs',
#   'Job Title': 'Machine Learning Engineer || Florida/chandigarh Location',
#   'Key Skills': 'GIT| Linux| Machine Learning|Python',
#   'Location': 'Los Angeles',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 367,
#   'Industry': 'Recruitment, Staffing',
#   'Job Experience Required': '5 - 8 yrs',
#   'Job Title': 'Sr. Cloud Developer',
#   'Key Skills': 'SQL|Python| Analytics| Machine learning| Solution architecture| Analytical| SCALA| Cosmos| Programming| Data warehousing',
#   'Location': 'Austin',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 387,
#   'Industry': 'BPO, Call Centre, ITeS',
#   'Job Experience Required': '6 - 8 yrs',
#   'Job Title': 'PERL Developer',
#   'Key Skills': 'Python| Six Sigma| PMP| .NET| HTML| JavaScript| SQL| Oracle| assembly language| Real Time Operating Systems',
#   'Location': 'Los Angeles',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 393,
#   'Industry': 'Medical, Healthcare, Hospitals',
#   'Job Experience Required': '5 - 10 yrs',
#   'Job Title': 'Data Science Engineer',
#   'Key Skills': 'Unix| data science| SQL| Linux| SAS| HTML| Perl| SDLC| Android|Python',
#   'Location': 'Seattle',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - DBA , Datawarehousing',
#   'Id': 412,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '3 - 5 yrs',
#   'Job Title': 'Senior Business Analyst - Sql/Python',
#   'Key Skills': 'data analysis| vba| macros| advanced excel| oracle sql| google analytics| business analysis|Python| data mining| business analyst',
#   'Location': 'New York',
#   'Role': 'Business Analyst',
#   'Role Category': 'System Design/Implementation/ERP/CRM'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 448,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '3 - 6 yrs',
#   'Job Title': 'Python Manager - IIT/ IIM/ DSE/ ISI',
#   'Key Skills': 'Microstrategy| Business Intelligence| Cognos| Business Objects| Tableau| AWS|Python| SQL',
#   'Location': 'Boston',
#   'Role': 'IT/Networking-Manager',
#   'Role Category': 'Admin/Maintenance/Security/Datawarehousing'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 453,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '5 - 10 yrs',
#   'Job Title': 'Senior Drupal Developer',
#   'Key Skills': 'Drupal| Linux| MySQL|Python| Consulting| Procurement| Monitoring| Front end| Backend| Django',
#   'Location': 'Austin',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 461,
#   'Industry': 'Advertising, PR, MR, Event Management',
#   'Job Experience Required': '3 - 5 yrs',
#   'Job Title': 'QA - Associate , - Business - Operations - DM',
#   'Key Skills': 'QA| Data management| GDB| Fixed income| Data quality| HTTP| Operations|Python',
#   'Location': 'Boston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'Analytics & Business Intelligence',
#   'Id': 465,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 6 yrs',
#   'Job Title': 'Data Scientist - Sql/nosql',
#   'Key Skills': 'SQL| NoSQL| R|Python| Scala| Data Visualization| Machine Learning| Data Science| Data Modeling| Algorithm',
#   'Location': 'Austin',
#   'Role': 'Data Analyst',
#   'Role Category': 'Analytics & BI'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 482,
#   'Industry': 'Accounting, Finance',
#   'Job Experience Required': '4 - 8 yrs',
#   'Job Title': 'Specialist - DV',
#   'Key Skills': 'Javascript| SQL|Python| design studio| Strategy consulting| Front end| big data analytics| QlikView| MATLAB',
#   'Location': 'Austin',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 577,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 6 yrs',
#   'Job Title': 'Senior Software Engineer/ Team Lead -Python/ Django',
#   'Key Skills': 'Python| MySQL| Redis| NoSQL| Django| MongoDB| Postgresql| Data Structures| AWS| Algorithms',
#   'Location': 'New York',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 579,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '1 - 4 yrs',
#   'Job Title': 'Software Engineer - Node.js/ Java/Python',
#   'Key Skills': 'Java| C++| C| Ruby on Rails| Django| Node.js| Algorithm| Data Structure|Python',
#   'Location': 'Washington DC',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Telecom Software',
#   'Id': 644,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '5 - 10 yrs',
#   'Job Title': 'Technical Leader/technical Manager',
#   'Key Skills': 'Python| orchestration| Linux| telecom domain| product development| design| vmware| openstack| shell scripting| ansible',
#   'Location': 'Seattle',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 713,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '3 - 6 yrs',
#   'Job Title': 'Tcs Florida is Hiring forPython Developers',
#   'Key Skills': 'L3 Protocols| L2|Python| IP Networking| Microservices',
#   'Location': 'San Francisco',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - System Programming',
#   'Id': 718,
#   'Industry': 'Automobile, Auto Anciliary, Auto Components',
#   'Job Experience Required': '2 - 5 yrs',
#   'Job Title': 'ECF3 _ Linux Test development',
#   'Key Skills': 'UML| Perl|Python| White box testing| Automation testing| GIT| OOAD| Linux kernel| X86| Programming',
#   'Location': 'Detroit',
#   'Role': 'Team Lead/Technical Lead',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 739,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '10 - 12 yrs',
#   'Job Title': 'Senior Director - Service Engineering | 23499',
#   'Key Skills': 'Unix| Automation| Project management| Debugging| Javascript| PHP| Perl| Windows|Python',
#   'Location': 'Los Angeles',
#   'Role': 'Head/VP/GM-Technology(IT)/CTO',
#   'Role Category': 'Senior Management'},
#  {'Functional Area': 'IT Software - Other',
#   'Id': 744,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '1 - 3 yrs',
#   'Job Title': 'Python/django Developer',
#   'Key Skills': 'front end|Python| django| backend| mysql| javascript| D3.Js',
#   'Location': 'Seattle',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Other',
#   'Id': 774,
#   'Industry': 'Education, Teaching, Training',
#   'Job Experience Required': '2 - 6 yrs',
#   'Job Title': 'Business Analyst',
#   'Key Skills': 'Analytics| SQL| CRM| Data modeling| Cognos|Python| data cleansing| Performance optimization| Data analysis| Excel',
#   'Location': 'Detroit',
#   'Role': 'Business Analyst',
#   'Role Category': 'System Design/Implementation/ERP/CRM'},
#  {'Functional Area': 'IT Software - Embedded , EDA , VLSI , ASIC , Chip Design',
#   'Id': 787,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '1 - 5 yrs',
#   'Job Title': 'Embedded Engineer',
#   'Key Skills': 'assembly language| Six Sigma| PMP| JavaScript| .NET| HTML| Oracle| embedded|Python| SQL',
#   'Location': 'Seattle',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 805,
#   'Industry': 'IT-Software / Software Services',
#   'Job Experience Required': '4 - 9 Years',
#   'Job Title': 'Python Scripting Professional',
#   'Key Skills': 'Python|django|unix shell scripting|web technologies|web development|machine learning|application development|agile methodology',
#   'Location': 'Austin',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'Medical , Healthcare , R&D , Pharmaceuticals , Biotechnology',
#   'Id': 806,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 7 yrs',
#   'Job Title': 'Role 1 : Data Scientist',
#   'Key Skills': 'Linux|Python| Coding| Open source| Machine learning| big data| Basic| spark| hdfs| SCALA',
#   'Location': 'Austin',
#   'Role': 'Administration Services/Medical Facilities',
#   'Role Category': 'Medical Professional'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 812,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 6 yrs',
#   'Job Title': 'RLEME_R4_Developers_Bangalore',
#   'Key Skills': 'Developer|Python| MATLABProgramming| Testing| Application engineering| C| Technical| Mechanical',
#   'Location': 'San Francisco',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 845,
#   'Industry': 'IT-Software / Software Services',
#   'Job Experience Required': '6 - 11 Years',
#   'Job Title': 'Devops -Python :oracle-bangalore',
#   'Key Skills': 'git|oracle|sed|awk|build|linux|jenkins|hudson|unix|Python',
#   'Location': 'Seattle',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - System Programming',
#   'Id': 846,
#   'Industry': 'IT-Software / Software Services',
#   'Job Experience Required': '5 - 10 Years',
#   'Job Title': 'Senior Devops Engineer',
#   'Key Skills': 'Maintenance|Disaster Recovery|DevOps Engineer|Bash|Shell|Python|AWS services|Hadoop servers',
#   'Location': 'Detroit',
#   'Role': 'System Administrator',
#   'Role Category': 'Admin/Maintenance/Security/Datawarehousing'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 879,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '6 - 11 yrs',
#   'Job Title': 'Content Engineer Industrial (Senior Engineer)',
#   'Key Skills': 'Oracle| Linux| MySQL| Windows| Solaris| Aix| Automation|Python| Information security| HP-UX',
#   'Location': 'San Francisco',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 909,
#   'Industry': 'Education, Teaching, Training',
#   'Job Experience Required': '3 - 5 yrs',
#   'Job Title': 'Software Engineer',
#   'Key Skills': 'Python| Application development| Agile| Debugging| Machine learning| Log analysis| Automation testing| deep learning| Individual Contributor| Web technologies',
#   'Location': 'Los Angeles',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 921,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '3 - 5 yrs',
#   'Job Title': 'PHP Developers',
#   'Key Skills': 'assembly language| website| C| HTML| ajax| javascript| jquery| SQL| xhtml| Six Sigma| PMP| xml| linux| .NET| Oracle|Python',
#   'Location': 'Austin',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - DBA , Datawarehousing',
#   'Id': 974,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '9 - 14 yrs',
#   'Job Title': 'Principal Engineer - Java/big Data',
#   'Key Skills': 'Java| Open Source| Scala| Big Data| Spark| Performance Tuning|Python',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Other',
#   'Id': 985,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '7 - 10 yrs',
#   'Job Title': 'Lead Data Scientist',
#   'Key Skills': 'Python| Machine learning| Forecasting| Text mining| Neural networks| Natural language processing| text analytics| Logistic regression| advanced analytics| deep learning',
#   'Location': 'Boston',
#   'Role': 'Team Lead/Technical Lead',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1011,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '3 - 5 yrs',
#   'Job Title': 'Senior PHP with Drupal Developer',
#   'Key Skills': 'C|Python| assembly language| software| HTML| ajax| jquery| scripting| database| web| xml| linux| design| .NET| mysql| Oracle| website| javascript| SQL| xhtml| Six Sigma| PMP| drupal| php| support| applications',
#   'Location': 'Washington DC',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1030,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '5 - 9 yrs',
#   'Job Title': 'Sr. Full Stack Developer_fort (Arizona)react & Node/Python is Mandatory',
#   'Key Skills': 'react.js| node.js|Python| Senior Software Developer| senior software engineer| aws',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1039,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '3 - 5 yrs',
#   'Job Title': 'DEV OPS ENGINEER',
#   'Key Skills': 'C++| Linux| Information security| Debugging| Application development| Windows| Troubleshooting| Virtualization| SQL|Python',
#   'Location': 'New York',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1047,
#   'Industry': 'Office Equipment, Automation',
#   'Job Experience Required': '3 - 5 yrs',
#   'Job Title': 'Golang, Unix/Linux Developer',
#   'Key Skills': 'Unix| Linux| MySQL| Computer science| Software design| DNS| Data structures| Perl| HTTP|Python',
#   'Location': 'Austin',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1057,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '1 - 5 yrs',
#   'Job Title': 'Python Developer',
#   'Key Skills': 'SQL| Javascript|Python| rest| development| gaming| technical| software| testing| mobile| it| CSS3| Technical documentation| quality| Backend| Front end| Web services| HP data protector| ui| web| design| Software development life cycle| developer',
#   'Location': 'Boston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1081,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 5 yrs',
#   'Job Title': 'System Architect - Linux',
#   'Key Skills': 'Chef| Unix| Linux| TCP| Automation|Python| CMS| Troubleshooting| DNS| Ruby',
#   'Location': 'New York',
#   'Role': 'Technical Architect',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1117,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 6 yrs',
#   'Job Title': 'Full Stack Developer -Python & Java',
#   'Key Skills': 'Javascript| Application development|Python| Maven| development| css| DOM| software| JSON| nosql| spring| database| Version control| GIT| java| automation| RDBMS| Analytical| developer| api| mongodb',
#   'Location': 'Seattle',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1139,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '8 - 13 yrs',
#   'Job Title': 'Python Tester -New York',
#   'Key Skills': 'Selenium| Android| Java| Automation Testing| Jenkins| Continuous Integration|Python| GIT| SVN| Agile Development',
#   'Location': 'New York',
#   'Role': 'Technical Architect',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1250,
#   'Industry': 'Medical, Healthcare, Hospitals',
#   'Job Experience Required': '5 - 10 yrs',
#   'Job Title': 'Analytics Delivery Manager',
#   'Key Skills': 'Linux| HTML| SQL| Computer science| Coding| MySQL| Windows| Analytics| Android|Python',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - DBA , Datawarehousing',
#   'Id': 1263,
#   'Industry': 'Media, Entertainment, Internet',
#   'Job Experience Required': '5 - 6 yrs',
#   'Job Title': 'Senior Data Scientist',
#   'Key Skills': 'Python| Business intelligence| Coding| Computer science| Machine learning| Hbase| MongoDb| NoSQL| Cassandra| Operations',
#   'Location': 'Detroit',
#   'Role': 'Team Lead/Technical Lead',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1282,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 5 yrs',
#   'Job Title': 'Power BI',
#   'Key Skills': 'CSS| Power Bi| XML| Web Technologies| .Net| HTML| JSON|Python',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - System Programming',
#   'Id': 1286,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '5 - 7 yrs',
#   'Job Title': 'Staff Engineer - Cloud Platforms',
#   'Key Skills': 'Chief Executive Officer| Networking|Python| Distribution system| Data processing| Team building| big data| Cloud| Operating systems| AWS',
#   'Location': 'Houston',
#   'Role': 'Technical Architect',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'Financial Services , Banking , Investments , Insurance',
#   'Id': 1296,
#   'Industry': 'Banking, Financial Services, Broking',
#   'Job Experience Required': '10 - 12 yrs',
#   'Job Title': 'Chief Risk Officer - Credit Cards',
#   'Key Skills': 'Relationship management| Risk analytics| Coding| Risk assessment| Workflow| Risk management| Business intelligence| Stakeholder management| Forecasting|Python',
#   'Location': 'Houston',
#   'Role': 'Domestic Private Banking-Executive/Manager',
#   'Role Category': 'Retail/Personal Banking'},
#  {'Functional Area': 'IT Software - QA & Testing',
#   'Id': 1311,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 4 yrs',
#   'Job Title': 'Engineer - Testing',
#   'Key Skills': 'Automation| 3G| Networking| Spirent| volte| Protocol stack| Perl| IMS|Python| Testing',
#   'Location': 'Houston',
#   'Role': 'Testing Engineer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1313,
#   'Industry': 'Banking, Financial Services, Broking',
#   'Job Experience Required': '1 - 5 yrs',
#   'Job Title': 'Opening For a Coding Expert with Finance Background(1 yr Contract)',
#   'Key Skills': 'macros| data analysis| vba| Coding| data mining| process optimization| reporting|Python| SQL',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'Analytics & Business Intelligence',
#   'Id': 1350,
#   'Industry': 'IT-Software / Software Services',
#   'Job Experience Required': '2 - 6 Years',
#   'Job Title': 'Big Data Engineer',
#   'Key Skills': 'Java|Hadoop|Python|C++|Spark|Machine Learning|NoSQL|Oozie|Big Data|Languages',
#   'Location': 'Houston',
#   'Role': 'Data Analyst',
#   'Role Category': 'Analytics & BI'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1361,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '5 - 9 yrs',
#   'Job Title': 'Manager DBA || Payment Gateway',
#   'Key Skills': 'oracle and dba| Linux Administration| Database Administration| dba| Team Management Skills| sql and dba| MySQL| Bash| AWS|Python',
#   'Location': 'Houston',
#   'Role': 'DBA',
#   'Role Category': 'Admin/Maintenance/Security/Datawarehousing'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1366,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 5 yrs',
#   'Job Title': 'Web Developer',
#   'Key Skills': 'C| Six Sigma|Python| assembly language| HTML| SQL| PMP| web| JavaScript| .NET| developer| Oracle',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'Teaching , Education , Training , Counselling',
#   'Id': 1374,
#   'Industry': 'NGO, Social Services, Regulators, Industry Associations',
#   'Job Experience Required': '2 - 5 yrs',
#   'Job Title': 'Professor Madhu Viswanathan',
#   'Key Skills': 'Professor| Data analysis| Research Associate| CVS| Social media| Data collection| Programming| Research| Marketing Associate|Python',
#   'Location': 'Houston',
#   'Role': 'Lecturer/Professor',
#   'Role Category': 'University Level'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1407,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '5 - 10 yrs',
#   'Job Title': 'Immediate openings For system admin New Jersey location',
#   'Key Skills': 'Linux Administration| Azure| Bash Scripting| System Administration| system admin| AWS|Python',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - DBA , Datawarehousing',
#   'Id': 1411,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 5 yrs',
#   'Job Title': 'Big Data Developer - Tableau/Python/r',
#   'Key Skills': 'Tableau| SAS| R|Python| Spark| Machine Learning| RDBMS| SQL| Hadoop| Startup| Big Data',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1435,
#   'Industry': 'IT-Software / Software Services',
#   'Job Experience Required': '5 - 7 Years',
#   'Job Title': 'Python Scripting',
#   'Key Skills': 'Python|MATLAB|Image processing|Outsourcing|SCALA|Operations|Text mining|Opencv|deep learning|C',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1451,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '0 - 5 yrs',
#   'Job Title': 'Urgently Required : Mobile Automation Engineer',
#   'Key Skills': 'Appium| Webdriver| QA Automation| Cucumber| Selenium| IOS| Automation Testing| Java| Android|Python| Core Java',
#   'Location': 'Houston',
#   'Role': 'Quality Assurance/Quality Control Executive',
#   'Role Category': 'QA/Testing/Documentation'},
#  {'Functional Area': 'Medical , Healthcare , R&D , Pharmaceuticals , Biotechnology',
#   'Id': 1489,
#   'Industry': 'KPO, Research, Analytics',
#   'Job Experience Required': '3 - 8 yrs',
#   'Job Title': 'Senior Data Scientist Bidgely',
#   'Key Skills': 'Computer science| Data analysis| Analytical| Machine learning| Tools| Data mining| MATLAB| Monitoring| Analytics|Python',
#   'Location': 'Houston',
#   'Role': 'Research Scientist',
#   'Role Category': 'R&D'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1544,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 7 yrs',
#   'Job Title': 'Java Application Developer',
#   'Key Skills': 'Java Application Developer| C|Python| Six Sigma| PMP| .NET| HTML| SQL| Oracle| assembly language| Real Time Operating Systems| website| linux| xml| javascript| ajax| xhtml| jquery',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1551,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '4 - 8 yrs',
#   'Job Title': 'Software Engineer 2',
#   'Key Skills': 'Java| C++| OS| Cloud Foundry| Linux| Software Engineering| Bash| Object Oriented Programming| Ruby|Python',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1600,
#   'Industry': 'Travel , Hotels , Restaurants , Airlines , Railways',
#   'Job Experience Required': '2 - 5 yrs',
#   'Job Title': 'Dev Operations Engineer',
#   'Key Skills': 'C|Python| Six Sigma| PMP| .NET| HTML| JavaScript| SQL| Oracle| assembly language| Real Time Operating Systems',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'Analytics & Business Intelligence',
#   'Id': 1624,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 5 yrs',
#   'Job Title': 'Senior Business Analyst/ Assistant Manager/ Manager - Machine Learning',
#   'Key Skills': 'Deep Learning| Machine Learning| Natural Language Processing| Neural Networks| NLP| Information Retrieval| R| Computer Vision|Python| SAS',
#   'Location': 'Houston',
#   'Role': 'Analytics Manager',
#   'Role Category': 'Analytics & BI'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1633,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '4 - 6 yrs',
#   'Job Title': 'Tools Development Engineer',
#   'Key Skills': 'C++| Networking| Perl| rest| Network programming| development| C| Windows| tools| programming|Python| Scripting',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1641,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '9 - 13 yrs',
#   'Job Title': 'Perl Developer/ Sr.developer/ Lead',
#   'Key Skills': 'Java| Perforce| OOPS| Perl| Rest| XML| Javascript| Ruby| Web Services| Catalyst|Python',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1706,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '0 - 3 yrs',
#   'Job Title': 'Python Developer',
#   'Key Skills': 'Data Science| Data Analytics|Python',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1723,
#   'Industry': 'Recruitment, Staffing',
#   'Job Experience Required': '2 - 4 yrs',
#   'Job Title': 'Android Developer',
#   'Key Skills': 'Six Sigma| C|Python| assembly language| PMP| JavaScript| .NET| HTML| Oracle| SQL',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1739,
#   'Industry': 'IT-Software / Software Services',
#   'Job Experience Required': '0 - 5 Years',
#   'Job Title': 'Software Engineer, :NO Resume Campaign C++,Python',
#   'Key Skills': 'Java|Oracle SQL|HTML|C++|Software Engineering|Python|Unix|MVC|Html5|Spring',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1781,
#   'Industry': 'Medical, Healthcare, Hospitals',
#   'Job Experience Required': '2 - 3 yrs',
#   'Job Title': 'PHP DEVELOPER PROGRAMMER',
#   'Key Skills': 'C| Account management| PHP| assembly language| HTML| SQL| Six Sigma| PMP| JavaScript| .NET| Oracle|Python',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1806,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '5 - 8 yrs',
#   'Job Title': 'Delivery Module Lead',
#   'Key Skills': 'Unix| Automation| TIBCO| Test cases| Oracle| Teradata| cisco| Analytics| SQL|Python',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1848,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 3 yrs',
#   'Job Title': 'Software Engineer',
#   'Key Skills': 'Automation| cisco|Python| automation framework| server| Automation testing| development| testing| Management| GIT| API Testing| api',
#   'Location': 'Houston',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1883,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '3 - 8 yrs',
#   'Job Title': 'Senior Full Stack Developer',
#   'Key Skills': 'Javascript| SQL| Linux| server| css| technical| software| developing| HTML| JSON| Adobe| tools| NoSQL| web| devops| design| programming|Python| architecture| github| development| mobile| Apache| application| saas| applications',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1890,
#   'Industry': 'Banking / Financial Services / Broking',
#   'Job Experience Required': '3 - 8 Years',
#   'Job Title': 'Software Development Associate',
#   'Key Skills': 'c++|Python',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1906,
#   'Industry': 'Banking, Financial Services, Broking',
#   'Job Experience Required': '2 - 5 yrs',
#   'Job Title': 'Java / Scala Dev',
#   'Key Skills': 'Db2| Coding| Debugging| Agile| Application development| Investment banking| Open source| Middleware| SDLC|Python',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1964,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 4 yrs',
#   'Job Title': 'Delv Software Engineer',
#   'Key Skills': 'Python| Apache| SQL| Maven| metadata| c++| technical| software| microsoft| microservices| spring| java| design| Agile| api| programming| rest| development| Data structures| Analytics| Computer science| GIT| application| aws',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1967,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '5 - 9 yrs',
#   'Job Title': 'Fullstack Developer - Bangalore - Domlur',
#   'Key Skills': 'HTML| CSS| Java| Node.Js| DOM| React.Js| Grunt| Web Technologies|Python| .Net',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 1970,
#   'Industry': 'IT-Software / Software Services',
#   'Job Experience Required': '3 - 8 Years',
#   'Job Title': 'Cloud Operation Support Engineer : Oracle Bangalore',
#   'Key Skills': 'Python|customer operations|operational support|product support|cloud desktop support engineer|cloud technical support|cloud support engineer|cloud product support|cloud support|cloud application support|cloud customer support engineer',
#   'Location': 'Detroit',
#   'Role': 'Technical Support Engineer',
#   'Role Category': 'Admin/Maintenance/Security/Datawarehousing'},
#  {'Functional Area': 'IT Software - QA & Testing',
#   'Id': 1999,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '3 - 7 yrs',
#   'Job Title': 'Openstack Testing Engineer',
#   'Key Skills': 'Embedded Linux| Openstack|Python| Test Engineering| L2| L3',
#   'Location': 'Detroit',
#   'Role': 'Testing Engineer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Network Administration , Security',
#   'Id': 2040,
#   'Industry': 'Recruitment, Staffing',
#   'Job Experience Required': '3 - 8 yrs',
#   'Job Title': 'Devops Engg',
#   'Key Skills': 'C|Python| Six Sigma| PMP| .NET| HTML| JavaScript| SQL| Oracle| assembly language| Real Time Operating Systems',
#   'Location': 'Detroit',
#   'Role': 'System Administrator',
#   'Role Category': 'Admin/Maintenance/Security/Datawarehousing'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 2055,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 7 yrs',
#   'Job Title': 'PHP Developers and Senior PHP Developers',
#   'Key Skills': 'javascript| linux| mysql| ajax| perl| jquery| project management| software development| mca|Python',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 2057,
#   'Industry': 'Recruitment, Staffing',
#   'Job Experience Required': '2 - 7 yrs',
#   'Job Title': 'Java Developer',
#   'Key Skills': 'Technical| design| integration PHP| MySQL| HTML| SQL| DBA| Technology| Business Analysts| Architects| Lead Developers| JAVA| Architect| C|Python| Six Sigma',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'Analytics & Business Intelligence',
#   'Id': 2058,
#   'Industry': 'KPO, Research, Analytics',
#   'Job Experience Required': '5 - 10 yrs',
#   'Job Title': 'Manager Analytics',
#   'Key Skills': 'R| project management| SAS| statistical modelling|Python',
#   'Location': 'Detroit',
#   'Role': 'Analytics Manager',
#   'Role Category': 'Analytics & BI'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 2069,
#   'Industry': 'IT-Software / Software Services',
#   'Job Experience Required': '3 - 6 Years',
#   'Job Title': 'Python Scripting',
#   'Key Skills': 'Business process|Customer acquisition|Data quality|Outsourcing|Operations|Analytics|SQL|Data extraction|Python|Scripting',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Embedded , EDA , VLSI , ASIC , Chip Design',
#   'Id': 2072,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 5 yrs',
#   'Job Title': 'Validation Engineer',
#   'Key Skills': 'Unix| EthernetPython| PCIE| JTAG| SPI| MIPS| Silicon| Testing',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'Analytics & Business Intelligence',
#   'Id': 2098,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '6 - 7 yrs',
#   'Job Title': 'BI & Analytics Engineer',
#   'Key Skills': 'Data Science| Predictive Modeling| R| Alteryx| Data Analysis| Tableau| Data Analytics| SQL|Python| Marketing',
#   'Location': 'Detroit',
#   'Role': 'Analytics Manager',
#   'Role Category': 'Analytics & BI'},
#  {'Functional Area': 'Analytics & Business Intelligence',
#   'Id': 2105,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 5 yrs',
#   'Job Title': 'Python Developer - Analytics, Bangalore',
#   'Key Skills': 'analytics|Python| data science',
#   'Location': 'Detroit',
#   'Role': 'Data Analyst',
#   'Role Category': 'Analytics & BI'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 2107,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '7 - 12 yrs',
#   'Job Title': 'Data Engineer - Aryaka Bangalore',
#   'Key Skills': 'hive|Python| java| mapreduce| spark| cassandra| mysql| big data| hbase| pig',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 2118,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '4 - 9 yrs',
#   'Job Title': 'Python Software Developers',
#   'Key Skills': 'Python| data structures|Python developer',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - QA & Testing',
#   'Id': 2153,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '4 - 8 yrs',
#   'Job Title': 'FC/FCoE QA Engineer',
#   'Key Skills': 'Perl| Firmware|Python| automation framework| Networking protocols| Test scripts| Coding| Test execution| Virtualization| Software quality assurance',
#   'Location': 'Detroit',
#   'Role': 'Testing Engineer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 2272,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 7 yrs',
#   'Job Title': 'Data Engineer',
#   'Key Skills': 'Data Science| Java| NoSQL|Python| Spark| Artificial Intelligence| Machine Learning| Hadoop| SCALA| R',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 2278,
#   'Industry': 'Banking, Financial Services, Broking',
#   'Job Experience Required': '2 - 5 yrs',
#   'Job Title': 'Software Developer',
#   'Key Skills': 'assembly language| Six Sigma| PMP| JavaScript| .NET| HTML| Oracle|Python| SQL',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - System Programming',
#   'Id': 2316,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '2 - 7 yrs',
#   'Job Title': 'Full Stack Developer',
#   'Key Skills': 'Scrum|Python| Computer science| technical| software| Programming| tools| debugging| Object oriented programming| email| architecture| rest| level| mobile| Unit testing| quality| Backend| application| Web application| infrastructure| Cloud| developer| agile| aws',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'Production , Manufacturing , Maintenance',
#   'Id': 2341,
#   'Industry': 'Semiconductors, Electronics',
#   'Job Experience Required': '3 - 8 yrs',
#   'Job Title': 'Systems automation engineer',
#   'Key Skills': 'Linux| Perl| Server architecture| Software design| JTAG| Version control| SOC| Firmware| System software|Python',
#   'Location': 'Detroit',
#   'Role': 'Industrial Engineer',
#   'Role Category': 'Production/Manufacturing/Maintenance'},
#  {'Functional Area': 'IT Software - Network Administration , Security',
#   'Id': 2357,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '5 - 10 yrs',
#   'Job Title': 'Network Virtualization System Engineer - Unix/ Kernel/Python',
#   'Key Skills': 'Unix| VMware| Network Protocols| OpenStack| Troubleshooting| CCNP| Virtualization| Kernel| AWS| Network Operations Center|Python',
#   'Location': 'Detroit',
#   'Role': 'Network Administrator',
#   'Role Category': 'Admin/Maintenance/Security/Datawarehousing'},
#  {'Functional Area': 'IT Software - eCommerce , Internet Technologies',
#   'Id': 2386,
#   'Industry': 'BPO, Call Centre, ITeS',
#   'Job Experience Required': '2 - 3 yrs',
#   'Job Title': 'Website Developer',
#   'Key Skills': 'PHP| Javascript| MySQL| Ajax| jQuery| Joomla|Python| Wordpress| Data entry| Monitoring',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 2391,
#   'Industry': 'IT-Software / Software Services',
#   'Job Experience Required': '3 - 5 Years',
#   'Job Title': 'An Urgent Opening For full Stack Developer- Core Java/Python, Chennai',
#   'Key Skills': 'Angularjs|Python|CSS|full stack developer|JSON|HTML|Python developer|data ex|core java|node.js|apache|data modeling|oops|j2ee',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'},
#  {'Functional Area': 'IT Software - Application Programming , Maintenance',
#   'Id': 2417,
#   'Industry': 'IT-Software, Software Services',
#   'Job Experience Required': '5 - 10 yrs',
#   'Job Title': 'Senior Backend Developer',
#   'Key Skills': 'Python| Front end| Backend| TDD| Django| Deployment| microservices| Head Business Development| Infrastructure| Training',
#   'Location': 'Detroit',
#   'Role': 'Software Developer',
#   'Role Category': 'Programming & Design'}]

# %%
api_url="http://127.0.0.1:5000/data"
def get_number_of_jobs_T(technology):
    #your code goes here
    payload = {"Key Skills": technology}
    response = requests.get(api_url, params=payload)
    data = response.json()
    number_of_jobs = len(data)
    return technology, number_of_jobs

# %% [markdown]
# Calling the function for Python and checking if it works.

# %%
get_number_of_jobs_T("Python")
# Out:
# ('Python', 1173)

# %% [markdown]
# #### Write a function to find number of jobs in US for a location of your choice

# %%
def get_number_of_jobs_L(location):
    #your code goes here
    payload = {"Location": location}
    response = requests.get(api_url, params=payload)
    data = response.json()
    number_of_jobs = len(data)
    return location, number_of_jobs

# %% [markdown]
# Call the function for Los Angeles and check if it is working.

# %%
#your code goes here
get_number_of_jobs_L('Los Angeles')
# Out:
# ('Los Angeles', 640)

# %% [markdown]
# ### Store the results in an excel file

# %% [markdown]
# Call the API for all the given technologies above and write the results in an excel spreadsheet.

# %% [markdown]
# If you do not know how create excel file using python, double click here for **hints**.
#
# <!--
#
# from openpyxl import Workbook        # import Workbook class from module openpyxl
# wb=Workbook()                        # create a workbook object
# ws=wb.active                         # use the active worksheet
# ws.append(['Country','Continent'])   # add a row with two columns 'Country' and 'Continent'
# ws.append(['Eygpt','Africa'])        # add a row with two columns 'Egypt' and 'Africa'
# ws.append(['India','Asia'])          # add another row
# ws.append(['France','Europe'])       # add another row
# wb.save("countries.xlsx")            # save the workbook into a file called countries.xlsx
#
#
# -->

# %% [markdown]
# Create a python list of all locations for which you need to find the number of jobs postings.

# %%
#your code goes here
locations_list = ['Los Angeles', 'New York', 'San Francisco', 'Washington DC', 'Seattle', 'Austin', 'Detroit']

# %% [markdown]
# Import libraries required to create excel spreadsheet

# %%
# your code goes here
from openpyxl import Workbook        # import Workbook class from module openpyxl

# %% [markdown]
# Create a workbook and select the active worksheet

# %%
# your code goes here
wb=Workbook()                        # create a workbook object
ws=wb.active                         # use the active worksheet

# %% [markdown]
# Find the number of jobs postings for each of the location in the above list.
# Write the Location name and the number of jobs postings into the excel spreadsheet.

# %%
#your code goes here
ws.append(['Location','Number of Jobs'])
for location in locations_list:
    loc, num_jobs = get_number_of_jobs_L(location)
    ws.append([loc, num_jobs])

# %% [markdown]
# Save into an excel spreadsheet named 'job-postings.xlsx'.

# %%
#your code goes here
wb.save('job-postings.xlsx')

# %%
import os
import pandas as pd

file_path = os.path.join(os.getcwd(),'job-postings.xlsx')
print(file_path)
df3=pd.read_excel(file_path)
print(df3)
# Out:
# /home/wsuser/work/job-postings.xlsx
#         Location  Number of Jobs
# 0    Los Angeles             640
# 1       New York            3226
# 2  San Francisco             435
# 3  Washington DC            5316
# 4        Seattle            3375
# 5         Austin             434
# 6        Detroit            3945

# %% [markdown]
# #### In the similar way, you can try for below given technologies and results  can be stored in an excel sheet.

# %% [markdown]
# Collect the number of job postings for the following languages using the API:
#
# *   C
# *   C#
# *   C++
# *   Java
# *   JavaScript
# *   Python
# *   Scala
# *   Oracle
# *   SQL Server
# *   MySQL Server
# *   PostgreSQL
# *   MongoDB

# %%
# your code goes here
tech_list = ['C', 'C#', 'C++', 'Java', 'JavaScript', 'Python', 'Scala', 'Oracle', 'SQL Server', 'MySQL Server', 'PostgreSQL', 'MongoDB']
wb1=Workbook()
ws1=wb1.active
ws1.append(['Technology', 'Number of Jobs'])
for technology in tech_list:
    tech, num_jobs = get_number_of_jobs_T(technology)
    ws1.append([tech, num_jobs])

wb1.save('job-postings_tech.xlsx')
file_path1 = os.path.join(os.getcwd(),'job-postings_tech.xlsx')
print(file_path1)
df4=pd.read_excel(file_path1)
print(df4)
# Out:
# /home/wsuser/work/job-postings_tech.xlsx
#       Technology  Number of Jobs
# 0              C           13498
# 1             C#             333
# 2            C++             305
# 3           Java            2609
# 4     JavaScript             355
# 5         Python            1173
# 6          Scala              33
# 7         Oracle             784
# 8     SQL Server             250
# 9   MySQL Server               0
# 10    PostgreSQL              10
# 11       MongoDB             174

# %% [markdown]
# ## Author

# %% [markdown]
# Ayushi Jain

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja
#
# Lakshmi Holla
#
# Malika

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2022-01-19        | 0.3     | Lakshmi Holla     | Added changes in the markdown      |
# | 2021-06-25        | 0.2     | Malika            | Updated GitHub job json link       |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2022 IBM Corporation. All rights reserved.
